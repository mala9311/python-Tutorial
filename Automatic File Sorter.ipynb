# %% [markdown]
# Automatic file sorter in the file explorer

# %%
import os, shutil

# %%
path = r"C:/file Explorer/"

# %%
file_name = os.listdir(path)

# %%
folder_name =['CSV Files', 'Image files', 'Text files']

for loop in range(0,3):
    if not os.path.exists(path + folder_name[loop]):
        print(path + folder_name[loop])
        os.makedirs(path + folder_name[loop])
# Out:
# C:/file Explorer/CSV Files
# C:/file Explorer/Image files
# C:/file Explorer/Text files

# %%
for file in file_name:
    if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".jpeg" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)
    elif ".txt" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
